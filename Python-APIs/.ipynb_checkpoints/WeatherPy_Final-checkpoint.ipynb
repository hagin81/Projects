# %% [markdown]
# **WeatherPy**

# %% [markdown]
# ** Analysis **

# %% [markdown]
# * Observed trend 1: The farther a city is above the equator the colder it is

# %% [markdown]
# * Observed trend 2: Even though two cities might be at the same distant from the equator on both ends, the cities above the equator appear to be colder than those below

# %% [markdown]
# * Observed trend 3: Humidity is dynamic based on the distance from the equator, wind speed and temperator

# %%
# dependencies
import numpy as np
import matplotlib.pyplot as plt
import requests 
import json
from citipy import citipy
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ** Generate Random Latitudes and Latitudes **

# %%
# generate random latitudes and longitutes
geo = []
for i in range(1500):
    lat = np.random.uniform(-90,90 )
    long = np.random.uniform(-180,180 )
    coord =  str(lat ) + ',' + str( long )
    geo.append( coord )

print(geo)
# Out:
# ['-76.95175889097548,92.82452461398117', '54.190428970564994,9.037781377265816', '70.57755699982349,116.65560093470458', '8.408278366171558,43.325599873884556', '9.959627055580157,-23.383288815060666', '-6.811824083731096,-152.51302518189055', '30.671242705172773,-90.42091297620055', '0.7364734401572832,-137.867589272091', '-45.89165079094604,45.12467414513526', '85.01457876393312,-28.516825969236777', '6.175592143573525,137.80342936284046', '-4.416761995952712,51.145943531419164', '-5.709369045669533,123.17332271178651', '-12.815136164723853,-28.742546706321832', '-44.41904777547249,-106.13550592383102', '-10.529421868973628,-160.7340685893229', '17.21705382778883,-142.69564616209993', '-36.82542728455556,107.74884899214521', '35.24781213882366,155.2871734275156', '49.594898652103865,-33.70399889713815', '-19.44514003929956,-48.78024658603712', '-73.9079298783603,13.758941577575285', '-71.88746955167184,56.41980100318648', '56.42447677117667,106.15383488871407', '-68.05624611090835,-129.39590160198932', '-34.962543431178204,34.173830156485394', '23.204994736393928,13.724811929784579', '11.657059413706747,-44.95880062883367', '-41.92841840948172,18.919164768156833', '-19.207978569530795,105.16979005000678', '37.57515807300163,-38.72281093922294', '53.83237797432642,50.36992768975179', '86.44678328765906,-26.48852735175717', '-19.10032301147797,132.7133397945118', '-66.93228266419483,39.553880310104745', '-83.92624786555156,-59.028108246243704', '14.103943939580006,-12.431807969238605', '-38.5802398668437,-91.88959914383169', '24.551719704077968,5.165407863452032', '-83.78822846912128,132.97944141980042', '15.424986768867768,-8.568842397139633', '-87.21232077336549,21.633049031191092', '-39.53400740125527,60.80804530483482', '-81.53213327933696,150.87964242772927', '-27.508741534049676,62.0098611451057', '-61.14961821456402,-22.804234998354843', '-40.01111267141665,-103.99835110061105', '88.41239722492926,177.29447336467666', '34.579301107611315,149.07750690447529', '-39.7487599699195,-91.5513302860123', '76.54141252132553,162.52121611122573', '25.397971176065184,-98.0353226172113', '-77.70438402550025,56.15383775897999', '36.73506884243271,159.69984702089124', '2.584266745353503,-153.65127384457517', '36.45828570606973,-120.5765611328489', '-56.88929925468888,-65.75475111394503', '-39.77133058176446,-132.53538632074327', '-28.272366774313184,-134.09204158141884', '66.2866173840118,92.47275732146358', '-31.14962215069133,-122.39915705813547', '-44.949341709604,31.675804507799967', '-75.65757845426643,73.78237150134308', '-63.88538890304215,160.94188790247256', '-52.509200897734644,-131.17505459432886', '74.24151807777551,-75.01936731019708', '51.469467940697456,87.16144309641811', '-1.7004093726351783,147.55279881574694', '-23.87426570281886,-59.81401094428185', '-48.764938429224905,7.41707265673034', '62.035198231626794,-155.16593235857417', '0.6834717631992078,-3.5269616466984246', '71.73530584981648,17.88202143507695', '51.434728389172335,100.06544947101952', '-56.36636660052586,45.751182889320205', '17.76787809667826,-167.05396402750046', '-40.72357066324705,141.97802413266572', '-48.6330586831939,-102.54295164850635', '-62.6847505165682,-55.585949347193576', '-79.08842859216188,81.67364276754472', '-72.45644712606364,-8.437758435394159', '-17.321324496938303,165.38234497357348', '-5.833009329180669,-123.6565451939166', '-85.60761226134164,127.04748217973338', '50.19368639910081,-101.51274921688513', '23.49330170239773,-48.69338492412783', '76.31587270912956,-128.93790178062966', '-45.827438295298435,-178.9194084979997', '-48.0896556650044,81.98135156604712', '-48.842656779156194,167.80638037260871', '19.048755133426155,-147.26922380535603', '-65.45894927772355,-137.6250374700366', '13.460679846926382,-32.40146665202158', '2.609998215416269,140.24694156473845', '4.314790390972277,-84.36746010316516', '74.4483397521636,-154.38496930596295', '-60.223247999900266,-130.06138136086247', '4.04800396518614,-54.161768633838875', '2 ...

# %% [markdown]
# ** Generate Cities List and Perform API Calls **

# %%
# loop over geo points and get city. country and weather data
api_key = 'db33280cde513587ec16a5cd5027a141'

data = {}
counter = 1 
for i in geo:
    lat = i.split(',')[0]
    long = i.split(',')[1]

    city = citipy.nearest_city( float(lat) , float(long) ).city_name
    country = citipy.nearest_city( float(lat) , float(long) ).country_code
    
    url = 'http://api.openweathermap.org/data/2.5/weather?q={},{}&units=Imperial&APPID={}'.format( city, country, api_key )
    r = requests.get( url )

    # check for valid response from API
    if r.status_code != 200:
        continue 
        
    response = r.json() 
    print('Processing record {} of set 1 | {}'.format(counter , city))
    print(url)
    
    # using the city as key for the dict ensures they are unique
    data[city] = response
    counter += 1
# Out:
# Processing record 1 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 2 of set 1 | cullman
# http://api.openweathermap.org/data/2.5/weather?q=cullman,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 3 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 4 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 5 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 6 of set 1 | brunswick
# http://api.openweathermap.org/data/2.5/weather?q=brunswick,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 7 of set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 8 of set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?q=padang,id&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 9 of set 1 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?q=xai-xai,mz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 10 of set 1 | tarakan
# http://api.openweathermap.org/data/2.5/weather?q=tarakan,id&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 11 of set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 12 of set 1 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?q=ahuimanu,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 13 of set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 14 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 15 of set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 16 of set 1 | emerald
# http://api.openweathermap.org/data/2.5/weather?q=emerald,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 17 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 18 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 19 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 20 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 21 of set 1 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?q=lufilufi,ws&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 22 of set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe,cv&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 23 of set 1 | korla
# http://api.openweathermap.org/data/2.5/weather?q=korla,cn&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 24 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 25 of set 1 | bestobe
# http://api.openweathermap.org/data/2.5/weather?q=bestobe,kz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 26 of set 1 | san gavino monreale
# http://api.openweathermap.org/data/2.5/weather?q=san gavino monreale,it&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 27 of set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 28 of set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria,sc&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 29 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 30 of set 1 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?q=antofagasta,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 31 of set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 32 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 33 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 34 of set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?q=lagoa,pt&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 35 of set 1 | sangar
# http://api.openweathermap.org/data/2.5/weather?q=sangar,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 36 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 37 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 38 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 39 of set 1 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?q=makakilo city,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 40 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 41 of set 1 | pekan
# http://api.openweathermap.org/data/2.5/weather?q=pekan,my&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 42 of set 1 | mackay
# http://api.openweathermap.org/data/2.5/weather?q=mackay,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 43 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 44 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 45 of set 1 | kjollefjord
# http://api.openweathermap.org/data/2.5/weather?q=kjollefjord,no&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 46 of set 1 | vardo
# http://api.openweathermap.org/data/2.5/weather?q=vardo,no&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 47 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 48 of set 1 | khandyga
# http://api.openweathermap.org/data/2.5/weather?q=khandyga,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 49 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 50 of set 1 | esmeraldas
# http://api.openweathermap.org/data/2.5/weather?q=esmeraldas,ec&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 51 of set 1 | bayan
# http://api.openweathermap.org/data/2.5/weather?q=bayan,kw&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 52 of set 1 | palmer
# http://api.openweathermap.org/data/2.5/weather?q=palmer,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 53 of set 1 | aykhal
# http://api.openweathermap.org/data/2.5/weather?q=aykhal,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 54 of set 1 | tinyahuarco
# http://api.openweathermap.org/data/2.5/weather?q=tinyahuarco,pe&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 55 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 56 of set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 57 of set 1 | san martin
# http://api.openweathermap.org/data/2.5/weather?q=san martin,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 58 of set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 59 of set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 60 of set 1 | acapulco
# http://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 61 of set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 62 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 63 of set 1 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 64 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 65 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 66 of set 1 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?q=sao joao da barra,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 67 of set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?q=east london,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 68 of set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 69 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 70 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 71 of set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 72 of set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 73 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 74 of set 1 | vao
# http://api.openweathermap.org/data/2.5/weather?q=vao,nc&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 75 of set 1 | puebloviejo
# http://api.openweathermap.org/data/2.5/weather?q=puebloviejo,ec&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 76 of set 1 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?q=port-gentil,ga&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 77 of set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 78 of set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 79 of set 1 | mount isa
# http://api.openweathermap.org/data/2.5/weather?q=mount isa,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 80 of set 1 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?q=sobolevo,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 81 of set 1 | college
# http://api.openweathermap.org/data/2.5/weather?q=college,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 82 of set 1 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti,in&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 83 of set 1 | port blair
# http://api.openweathermap.org/data/2.5/weather?q=port blair,in&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 84 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 85 of set 1 | pochutla
# http://api.openweathermap.org/data/2.5/weather?q=pochutla,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 86 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 87 of set 1 | orichi
# http://api.openweathermap.org/data/2.5/weather?q=orichi,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 88 of set 1 | altay
# http://api.openweathermap.org/data/2.5/weather?q=altay,cn&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 89 of set 1 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?q=saint-joseph,re&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 90 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 91 of set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 92 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 93 of set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 94 of set 1 | newport
# http://api.openweathermap.org/data/2.5/weather?q=newport,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 95 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 96 of set 1 | miguel hidalgo
# http://api.openweathermap.org/data/2.5/weather?q=miguel hidalgo,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 97 of set 1 | jacqueville
# http://api.openweathermap.org/data/2.5/weather?q=jacqueville,ci&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 98 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 99 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 100 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 101 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 102 of set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 103 of set 1 | lithakia
# http://api.openweathermap.org/data/2.5/weather?q=lithakia,gr&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 104 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 105 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 106 of set 1 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?q=zhanaozen,kz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 107 of set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 108 of set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 109 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 110 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 111 of set 1 | ipil
# http://api.openweathermap.org/data/2.5/weather?q=ipil,ph&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 112 of set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 113 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 114 of set 1 | acapulco
# http://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 115 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 116 of set 1 | san pedro
# http://api.openweathermap.org/data/2.5/weather?q=san pedro,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 117 of set 1 | palauig
# http://api.openweathermap.org/data/2.5/weather?q=palauig,ph&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 118 of set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 119 of set 1 | rakaia
# http://api.openweathermap.org/data/2.5/weather?q=rakaia,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 120 of set 1 | merauke
# http://api.openweathermap.org/data/2.5/weather?q=merauke,id&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 121 of set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 122 of set 1 | altay
# http://api.openweathermap.org/data/2.5/weather?q=altay,cn&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 123 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 124 of set 1 | khanpur
# http://api.openweathermap.org/data/2.5/weather?q=khanpur,pk&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 125 of set 1 | villa maria
# http://api.openweathermap.org/data/2.5/weather?q=villa maria,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 126 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 127 of set 1 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?q=tomatlan,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 128 of set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 129 of set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 130 of set 1 | pyapon
# http://api.openweathermap.org/data/2.5/weather?q=pyapon,mm&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 131 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 132 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 133 of set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 134 of set 1 | bonthe
# http://api.openweathermap.org/data/2.5/weather?q=bonthe,sl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 135 of set 1 | road town
# http://api.openweathermap.org/data/2.5/weather?q=road town,vg&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 136 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 137 of set 1 | polazna
# http://api.openweathermap.org/data/2.5/weather?q=polazna,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 138 of set 1 | anadyr
# http://api.openweathermap.org/data/2.5/weather?q=anadyr,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 139 of set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 140 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 141 of set 1 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?q=novyy urengoy,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 142 of set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy,uy&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 143 of set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 144 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 145 of set 1 | elko
# http://api.openweathermap.org/data/2.5/weather?q=elko,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 146 of set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 147 of set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik,fo&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 148 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 149 of set 1 | te anau
# http://api.openweathermap.org/data/2.5/weather?q=te anau,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 150 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg,mu&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 151 of set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint george,bm&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 152 of set 1 | beroroha
# http://api.openweathermap.org/data/2.5/weather?q=beroroha,mg&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 153 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 154 of set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 155 of set 1 | itarema
# http://api.openweathermap.org/data/2.5/weather?q=itarema,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 156 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 157 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 158 of set 1 | datong
# http://api.openweathermap.org/data/2.5/weather?q=datong,cn&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 159 of set 1 | fraga
# http://api.openweathermap.org/data/2.5/weather?q=fraga,es&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 160 of set 1 | muncie
# http://api.openweathermap.org/data/2.5/weather?q=muncie,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 161 of set 1 | noumea
# http://api.openweathermap.org/data/2.5/weather?q=noumea,nc&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 162 of set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 163 of set 1 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?q=lazaro cardenas,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 164 of set 1 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?q=santa cruz,cr&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 165 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 166 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 167 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 168 of set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 169 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 170 of set 1 | west wendover
# http://api.openweathermap.org/data/2.5/weather?q=west wendover,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 171 of set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria,sc&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 172 of set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 173 of set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 174 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 175 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 176 of set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?q=castro,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 177 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 178 of set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 179 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 180 of set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 181 of set 1 | pala
# http://api.openweathermap.org/data/2.5/weather?q=pala,td&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 182 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 183 of set 1 | te anau
# http://api.openweathermap.org/data/2.5/weather?q=te anau,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 184 of set 1 | newtownards
# http://api.openweathermap.org/data/2.5/weather?q=newtownards,gb&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 185 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 186 of set 1 | mehamn
# http://api.openweathermap.org/data/2.5/weather?q=mehamn,no&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 187 of set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?q=katsuura,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 188 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 189 of set 1 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba,bb&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 190 of set 1 | wageningen
# http://api.openweathermap.org/data/2.5/weather?q=wageningen,sr&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 191 of set 1 | ramshir
# http://api.openweathermap.org/data/2.5/weather?q=ramshir,ir&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 192 of set 1 | tarakan
# http://api.openweathermap.org/data/2.5/weather?q=tarakan,id&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 193 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 194 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 195 of set 1 | haines junction
# http://api.openweathermap.org/data/2.5/weather?q=haines junction,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 196 of set 1 | peniche
# http://api.openweathermap.org/data/2.5/weather?q=peniche,pt&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 197 of set 1 | takab
# http://api.openweathermap.org/data/2.5/weather?q=takab,ir&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 198 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 199 of set 1 | chumikan
# http://api.openweathermap.org/data/2.5/weather?q=chumikan,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 200 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 201 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 202 of set 1 | rechitsy
# http://api.openweathermap.org/data/2.5/weather?q=rechitsy,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 203 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 204 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 205 of set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 206 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 207 of set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?q=padang,id&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 208 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 209 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 210 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 211 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 212 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 213 of set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 214 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 215 of set 1 | waipawa
# http://api.openweathermap.org/data/2.5/weather?q=waipawa,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 216 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 217 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 218 of set 1 | rocha
# http://api.openweathermap.org/data/2.5/weather?q=rocha,uy&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 219 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 220 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 221 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 222 of set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?q=geraldton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 223 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 224 of set 1 | remanso
# http://api.openweathermap.org/data/2.5/weather?q=remanso,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 225 of set 1 | aykhal
# http://api.openweathermap.org/data/2.5/weather?q=aykhal,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 226 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 227 of set 1 | coremas
# http://api.openweathermap.org/data/2.5/weather?q=coremas,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 228 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 229 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 230 of set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 231 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 232 of set 1 | kovylkino
# http://api.openweathermap.org/data/2.5/weather?q=kovylkino,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 233 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 234 of set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 235 of set 1 | college
# http://api.openweathermap.org/data/2.5/weather?q=college,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 236 of set 1 | veraval
# http://api.openweathermap.org/data/2.5/weather?q=veraval,in&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 237 of set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 238 of set 1 | mbini
# http://api.openweathermap.org/data/2.5/weather?q=mbini,gq&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 239 of set 1 | kharp
# http://api.openweathermap.org/data/2.5/weather?q=kharp,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 240 of set 1 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?q=iracoubo,gf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 241 of set 1 | stillwater
# http://api.openweathermap.org/data/2.5/weather?q=stillwater,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 242 of set 1 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 243 of set 1 | port blair
# http://api.openweathermap.org/data/2.5/weather?q=port blair,in&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 244 of set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 245 of set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 246 of set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 247 of set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 248 of set 1 | teahupoo
# http://api.openweathermap.org/data/2.5/weather?q=teahupoo,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 249 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 250 of set 1 | miki
# http://api.openweathermap.org/data/2.5/weather?q=miki,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 251 of set 1 | suda
# http://api.openweathermap.org/data/2.5/weather?q=suda,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 252 of set 1 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?q=batagay-alyta,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 253 of set 1 | ustka
# http://api.openweathermap.org/data/2.5/weather?q=ustka,pl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 254 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 255 of set 1 | high level
# http://api.openweathermap.org/data/2.5/weather?q=high level,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 256 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 257 of set 1 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?q=nhulunbuy,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 258 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 259 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 260 of set 1 | hov
# http://api.openweathermap.org/data/2.5/weather?q=hov,no&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 261 of set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 262 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 263 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 264 of set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 265 of set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 266 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 267 of set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 268 of set 1 | port blair
# http://api.openweathermap.org/data/2.5/weather?q=port blair,in&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 269 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 270 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 271 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 272 of set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 273 of set 1 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?q=jacareacanga,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 274 of set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?q=ahipara,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 275 of set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 276 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 277 of set 1 | margate
# http://api.openweathermap.org/data/2.5/weather?q=margate,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 278 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 279 of set 1 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?q=cap malheureux,mu&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 280 of set 1 | talnakh
# http://api.openweathermap.org/data/2.5/weather?q=talnakh,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 281 of set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 282 of set 1 | hamilton
# http://api.openweathermap.org/data/2.5/weather?q=hamilton,bm&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 283 of set 1 | roma
# http://api.openweathermap.org/data/2.5/weather?q=roma,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 284 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 285 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 286 of set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 287 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 288 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 289 of set 1 | vondrozo
# http://api.openweathermap.org/data/2.5/weather?q=vondrozo,mg&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 290 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 291 of set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?q=poum,nc&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 292 of set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo,pt&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 293 of set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 294 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 295 of set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 296 of set 1 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?q=tazovskiy,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 297 of set 1 | senanga
# http://api.openweathermap.org/data/2.5/weather?q=senanga,zm&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 298 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 299 of set 1 | semypolky
# http://api.openweathermap.org/data/2.5/weather?q=semypolky,ua&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 300 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 301 of set 1 | acapulco
# http://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 302 of set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 303 of set 1 | fort frances
# http://api.openweathermap.org/data/2.5/weather?q=fort frances,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 304 of set 1 | anori
# http://api.openweathermap.org/data/2.5/weather?q=anori,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 305 of set 1 | yatou
# http://api.openweathermap.org/data/2.5/weather?q=yatou,cn&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# ...
# http://api.openweathermap.org/data/2.5/weather?q=walvis bay,na&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1186 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1187 of set 1 | peniche
# http://api.openweathermap.org/data/2.5/weather?q=peniche,pt&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1188 of set 1 | bennington
# http://api.openweathermap.org/data/2.5/weather?q=bennington,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1189 of set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1190 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1191 of set 1 | cleveland
# http://api.openweathermap.org/data/2.5/weather?q=cleveland,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1192 of set 1 | buraydah
# http://api.openweathermap.org/data/2.5/weather?q=buraydah,sa&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1193 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1194 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1195 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1196 of set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1197 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1198 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1199 of set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1200 of set 1 | sal rei
# http://api.openweathermap.org/data/2.5/weather?q=sal rei,cv&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1201 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1202 of set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy,uy&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1203 of set 1 | jalu
# http://api.openweathermap.org/data/2.5/weather?q=jalu,ly&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1204 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1205 of set 1 | sorland
# http://api.openweathermap.org/data/2.5/weather?q=sorland,no&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1206 of set 1 | tottori
# http://api.openweathermap.org/data/2.5/weather?q=tottori,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1207 of set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1208 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1209 of set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1210 of set 1 | kabanjahe
# http://api.openweathermap.org/data/2.5/weather?q=kabanjahe,id&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1211 of set 1 | pauini
# http://api.openweathermap.org/data/2.5/weather?q=pauini,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1212 of set 1 | arlit
# http://api.openweathermap.org/data/2.5/weather?q=arlit,ne&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1213 of set 1 | sulangan
# http://api.openweathermap.org/data/2.5/weather?q=sulangan,ph&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1214 of set 1 | petropavlovka
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovka,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1215 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1216 of set 1 | charters towers
# http://api.openweathermap.org/data/2.5/weather?q=charters towers,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1217 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1218 of set 1 | palora
# http://api.openweathermap.org/data/2.5/weather?q=palora,ec&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1219 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1220 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1221 of set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1222 of set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1223 of set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1224 of set 1 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1225 of set 1 | kabanjahe
# http://api.openweathermap.org/data/2.5/weather?q=kabanjahe,id&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1226 of set 1 | acapulco
# http://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1227 of set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1228 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1229 of set 1 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?q=bandarbeyla,so&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1230 of set 1 | behshahr
# http://api.openweathermap.org/data/2.5/weather?q=behshahr,ir&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1231 of set 1 | pula
# http://api.openweathermap.org/data/2.5/weather?q=pula,hr&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1232 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1233 of set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1234 of set 1 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?q=yarmouth,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1235 of set 1 | orbetello
# http://api.openweathermap.org/data/2.5/weather?q=orbetello,it&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1236 of set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1237 of set 1 | turbat
# http://api.openweathermap.org/data/2.5/weather?q=turbat,pk&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1238 of set 1 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?q=sobolevo,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1239 of set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1240 of set 1 | puerto colombia
# http://api.openweathermap.org/data/2.5/weather?q=puerto colombia,co&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1241 of set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?q=ahipara,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1242 of set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1243 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1244 of set 1 | kamenka
# http://api.openweathermap.org/data/2.5/weather?q=kamenka,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1245 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1246 of set 1 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?q=cockburn town,bs&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1247 of set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1248 of set 1 | bosaso
# http://api.openweathermap.org/data/2.5/weather?q=bosaso,so&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1249 of set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1250 of set 1 | vallenar
# http://api.openweathermap.org/data/2.5/weather?q=vallenar,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1251 of set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1252 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1253 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1254 of set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1255 of set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1256 of set 1 | san roque
# http://api.openweathermap.org/data/2.5/weather?q=san roque,ph&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1257 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1258 of set 1 | pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco,pe&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1259 of set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo,pt&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1260 of set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1261 of set 1 | namie
# http://api.openweathermap.org/data/2.5/weather?q=namie,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1262 of set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu,cl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1263 of set 1 | priboj
# http://api.openweathermap.org/data/2.5/weather?q=priboj,rs&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1264 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1265 of set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1266 of set 1 | bend
# http://api.openweathermap.org/data/2.5/weather?q=bend,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1267 of set 1 | sakaiminato
# http://api.openweathermap.org/data/2.5/weather?q=sakaiminato,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1268 of set 1 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?q=raudeberg,no&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1269 of set 1 | santona
# http://api.openweathermap.org/data/2.5/weather?q=santona,es&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1270 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1271 of set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1272 of set 1 | shimoda
# http://api.openweathermap.org/data/2.5/weather?q=shimoda,jp&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1273 of set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1274 of set 1 | bawku
# http://api.openweathermap.org/data/2.5/weather?q=bawku,gh&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1275 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1276 of set 1 | kurumkan
# http://api.openweathermap.org/data/2.5/weather?q=kurumkan,ru&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1277 of set 1 | abhar
# http://api.openweathermap.org/data/2.5/weather?q=abhar,ir&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1278 of set 1 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?q=thunder bay,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1279 of set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat,gl&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1280 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1281 of set 1 | mbulu
# http://api.openweathermap.org/data/2.5/weather?q=mbulu,tz&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1282 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1283 of set 1 | moron
# http://api.openweathermap.org/data/2.5/weather?q=moron,mn&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1284 of set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc,us&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141
# Processing record 1285 of set 1 | ngaoundere
# http://api.openweathermap.org/data/2.5/weather?q=ngaoundere,cm&units=Imperial&APPID=db33280cde513587ec16a5cd5027a141

# %%
# print number of unique cities
print( len(data) )
# Out:
# 545

# %%
# loop over the data from the api and extract the needed data
trimmed_data = []
for k,v in data.items():
        lat = v['coord']['lat']
        long = v['coord']['lon']
        temp_max = v['main']['temp_max']
        wind = v['wind']['speed']
        clouds = v['clouds']['all']
        country = v['sys']['country']
        date = v['dt']
        humidity = v['main']['humidity']
        trimmed_data.append( ( k, clouds, country, date, humidity, lat, long, temp_max, wind ) )

print(trimmed_data)
# Out:
# [('albany', 88, 'AU', 1519924377, 92, -35.02, 117.88, 55.97, 5.06), ('cullman', 20, 'US', 1519922100, 100, 34.17, -86.84, 60.8, 4.7), ('upernavik', 88, 'GL', 1519924483, 91, 72.79, -56.15, 20.06, 3.94), ('ushuaia', 40, 'AR', 1519920000, 81, -54.81, -68.31, 50, 20.8), ('punta arenas', 40, 'CL', 1519920000, 54, -53.16, -70.91, 55.4, 33.33), ('brunswick', 90, 'US', 1519923360, 93, 41.25, -81.83, 50, 11.41), ('dikson', 48, 'RU', 1519924407, 69, 73.51, 80.55, -1.64, 9.98), ('padang', 48, 'ID', 1519924196, 100, -0.92, 100.36, 82.52, 2.71), ('xai-xai', 24, 'MZ', 1519924197, 100, -25.04, 33.64, 75.86, 11.43), ('tarakan', 24, 'ID', 1519924198, 100, 3.3, 117.63, 80.27, 4.27), ('chokurdakh', 64, 'RU', 1519924394, 69, 70.62, 147.9, -5.46, 7.52), ('ahuimanu', 90, 'US', 1519919820, 73, 21.44, -157.84, 75.2, 11.41), ('arraial do cabo', 40, 'BR', 1519920000, 66, -22.97, -42.02, 87.8, 4.7), ('luderitz', 0, 'NA', 1519920000, 56, -26.65, 15.16, 73.4, 35.57), ('emerald', 20, 'AU', 1519924199, 89, -23.53, 148.16, 74.69, 5.39), ('rikitea', 48, 'PF', 1519924358, 99, -23.12, -134.97, 80.85, 18.37), ('tasiilaq', 5, 'GL', 1519923000, 72, 65.61, -37.64, 17.6, 4.7), ('lufilufi', 20, 'WS', 1519920000, 94, -13.87, -171.6, 77, 6.93), ('sao filipe', 0, 'CV', 1519923761, 92, 14.9, -24.5, 71.27, 10.65), ('korla', 12, 'CN', 1519924201, 74, 41.76, 86.15, 25.19, 2.59), ('busselton', 0, 'AU', 1519924359, 100, -33.64, 115.35, 61.41, 16.02), ('bestobe', 44, 'KZ', 1519923971, 68, 52.5, 73.1, 2.37, 10.54), ('san gavino monreale', 40, 'IT', 1519923300, 93, 39.55, 8.79, 60.8, 4.7), ('kavieng', 48, 'PG', 1519924467, 100, -2.57, 150.8, 82.38, 4.38), ('victoria', 75, 'SC', 1519920000, 74, -4.62, 55.45, 84.2, 9.17), ('tuktoyaktuk', 20, 'CA', 1519920000, 74, 69.44, -133.03, -22.01, 8.05), ('antofagasta', 20, 'CL', 1519920000, 56, -23.65, -70.4, 71.6, 11.41), ('butaritari', 76, 'KI', 1519924436, 100, 3.07, 172.79, 81.93, 11.99), ('jamestown', 0, 'SH', 1519924411, 100, -15.94, -5.72, 74.51, 11.77), ('lagoa', 40, 'PT', 1519921800, 82, 37.14, -8.45, 59, 25.28), ('sangar', 48, 'RU', 1519924205, 32, 63.92, 127.47, -22.29, 1.7), ('makakilo city', 40, 'US', 1519919820, 83, 21.35, -158.09, 75.2, 8.05), ('cape town', 20, 'ZA', 1519920000, 57, -33.93, 18.42, 75.2, 23.04), ('pekan', 75, 'MY', 1519920000, 88, 3.49, 103.39, 78.8, 2.24), ('mackay', 64, 'AU', 1519920000, 88, -21.15, 149.2, 77, 4.7), ('severo-kurilsk', 8, 'RU', 1519924019, 100, 50.68, 156.12, 17.49, 5.06), ('mar del plata', 8, 'AR', 1519923695, 32, -46.43, -67.52, 76.17, 7.52), ('kjollefjord', 90, 'NO', 1519923000, 92, 70.95, 27.35, 26.6, 1.12), ('vardo', 0, 'NO', 1519923000, 85, 70.37, 31.11, 21.2, 9.17), ('khandyga', 76, 'RU', 1519924208, 52, 62.65, 135.58, -18.33, 2.93), ('bredasdorp', 92, 'ZA', 1519920000, 56, -34.53, 20.04, 73.4, 17.22), ('esmeraldas', 40, 'EC', 1519920000, 52, -1.87, -79.8, 87.8, 6.93), ('bayan', 0, 'KW', 1519923600, 64, 29.3, 48.05, 69.8, 8.05), ('palmer', 1, 'US', 1519921260, 40, 61.6, -149.11, 17.6, 27.51), ('aykhal', 0, 'RU', 1519923793, 0, 65.95, 111.51, -31.11, 4.94), ('tinyahuarco', 56, 'PE', 1519924210, 78, -10.75, -76.3, 52.82, 3.83), ('ribeira grande', 75, 'PT', 1519921800, 66, 38.52, -28.7, 53.6, 10.29), ('kaitangata', 92, 'NZ', 1519924211, 98, -46.28, 169.85, 57.27, 4.16), ('san martin', 68, 'AR', 1519924212, 66, -24.71, -64.13, 81.3, 4.94), ('port alfred', 68, 'ZA', 1519924366, 92, -33.59, 26.89, 68.88, 10.76), ('acapulco', 5, 'MX', 1519918860, 69, 16.86, -99.88, 82.4, 5.73), ('bluff', 88, 'NZ', 1519924403, 98, -46.6, 168.33, 60.69, 9.98), ('fairbanks', 1, 'US', 1519919880, 74, 64.84, -147.72, -23.81, 6.96), ('sao joao da barra', 12, 'BR', 1519923774, 100, -21.64, -41.05, 79.68, 12.21), ('east london', 90, 'ZA', 1519920060, 94, -33.02, 27.91, 68, 4.7), ('bethel', 40, 'US', 1519923180, 72, 60.79, -161.76, 10.4, 9.17), ('nikolskoye', 0, 'RU', 1519921800, 78, 59.7, 30.79, 10.4, 4.47), ('yellowknife', 75, 'CA', 1519923600, 69, 62.45, -114.38, -7.61, 12.75), ('vao', 20, 'NC', 1519923783, 100, - ...

# %%
# data to Pandas dataframe 
df = pd.DataFrame( trimmed_data, columns=['City', 'Cloudiness','Country','Date', 'Humidity','Lat', 'Long', 'Max Temp','Wind Speed'] )
df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Long  \
# 0        albany          88      AU  1519924377        92 -35.02  117.88
# 1       cullman          20      US  1519922100       100  34.17  -86.84
# 2     upernavik          88      GL  1519924483        91  72.79  -56.15
# 3       ushuaia          40      AR  1519920000        81 -54.81  -68.31
# 4  punta arenas          40      CL  1519920000        54 -53.16  -70.91
#
#    Max Temp  Wind Speed
# 0     55.97        5.06
# 1     60.80        4.70
# 2     20.06        3.94
# 3     50.00       20.80
# 4     55.40       33.33

# %%
# save dataframe to CSV
df.to_csv('weather_data.csv')

# %% [markdown]
# ** Latitudes vs Temperature Plot**

# %%
#create variables out for x,y, then make scatter plot
color = ['blue']
df.plot(kind='scatter', x='Lat', y='Max Temp', color=color)
plt.title('City Latitudes vs. Max Temperature(03/01/18)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(F)')
plt.grid()

# %% [markdown]
# **City Latitude vs. Humidity (03/01/18)**

# %%
df.plot(kind='scatter', x ='Lat', y = 'Humidity', color=color)
plt.title('City Latitude vs. Humidity(03/01/18)')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.grid()

# %% [markdown]
# **City Latitude vs. Cloudiness (03/01/18)**

# %%
df.plot(kind='scatter', x = 'Lat', y = 'Cloudiness', color = color)
plt.title('City Latitude vs. Cloudiness (03/01/18)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.grid()

# %% [markdown]
# **City Latitude vs. Wind Speed (03/01/18)**

# %%
df.plot(kind='scatter', x = 'Lat', y = 'Wind Speed', color = color)
plt.title('City Latitude vs. Wind Speed (03/01/18)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.grid()
